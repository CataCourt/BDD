# %% [markdown]
# <a href="https://colab.research.google.com/github/CataCourt/BDD/blob/main/Gu%C3%ADa_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *texto en cursiva*#Guía: SQL
#
# En esta guía usted deberá realizar consultas SQL en un servidor virtual con PostgreSQL que contiene
# datos de películas extraídos de IMDb. El esquema de los datos es el siguiente:
#
# * $\color{green}{\textbf{pelicula}}(\color{blue}{\underline{\text{nombre}}}, \color{blue}{\underline{\text{anho}}}, \color{blue}{\text{calificacion}})$
# * $\color{green}{\textbf{actor}}(\color{blue}{\underline{\text{nombre}}}, \color{blue}{\text{genero}})$
# * $\color{green}{\textbf{personaje}}(\color{blue}{\underline{\text{p_nombre}}}, \color{blue}{\underline{\text{p_anho}}},  \color{blue}{\underline{\text{a_nombre}}}, \color{blue}{\underline{\text{personaje}}})$
#
# La tabla $\color{green}{\textbf{personaje}}$ usa llaves foráneas que hacen referencia a las tablas de $\color{green}{\textbf{actor}}(\color{blue}{\underline{\text{a_nombre}}})$ y $\color{green}{\textbf{pelicula}}(\color{blue}{\underline{\text{p_nombre}}}, \color{blue}{\underline{\text{p_anho}}})$.
#
# Para iniciar el servidor virtual, instalar la base de datos postgres, y descargar los datos e importarlos, debe correr el siguiente bloque:

# %%
# !git clone https://github.com/CataCourt/BDD
# Out:
# Cloning into 'BDD'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
# install
# !apt update
# !apt install postgresql postgresql-contrib &>log
# !service postgresql start
# !sudo -u postgres psql -c "CREATE USER root WITH SUPERUSER"
# set connection
# %load_ext sql
# %config SqlMagic.feedback=False
# %config SqlMagic.autopandas=True
# %sql postgresql+psycopg2://@/postgres
# !wget -cO - https://drive.google.com/uc\?export\=download\&id\=1g7UsolqIt5CatIUiWKQNiQ4sT6zsCZnk > /content/guia2.sql
# !psql postgres < /content/guia2.sql
# %sql set search_path to guia;
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 229 kB in 1s (158 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 45 packages can be upgraded. Run 'apt list --upgradable' to see them.
#  * Starting PostgreSQL 14 database server
#    ...done.
# ERROR:  role "root" already exists
# --2024-04-09 21:03:52--  https://drive.google.com/uc?export=download&id=1g7UsolqIt5CatIUiWKQNiQ4sT6zsCZnk
# Resolving drive.google.com (drive.google.com)... 108.177.127.102, 108.177.127.100, 108.177.127.113, ...
# Connecting to drive.google.com (drive.google.com)|108.177.127.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1g7UsolqIt5CatIUiWKQNiQ4sT6zsCZnk&export=download [following]
# --2024-04-09 21:03:52--  https://drive.usercontent.google.com/download?id=1g7UsolqIt5CatIUiWKQNiQ4sT6zsCZnk&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 108.177.127.132, 2a00:1450:4013:c07::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|108.177.127.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1220212 (1.2M) [application/octet-stream]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]   1.16M  --.-KB/s    in 0.01s
#
# 2024-04-09 21:03:53 (81.6 MB/s) - written to stdout [1220212/1220212]
#
# SET
# SET
# SET
# SET
# SET
#  set_config
# ------------
#
# (1 row)
#
# SET
# SET
# SET
# SET
# ERROR:  schema "guia" already exists
# SET
# SET
# ERROR:  relation "personaje" already exists
# ALTER TABLE
# ERROR:  relation "actor" already exists
# ALTER TABLE
# ERROR:  relation "pelicula" already exists
# ALTER TABLE
# ERROR:  duplicate key value violates unique constraint "actor_pkey"
# DETAIL:  Key (nombre)=(Aames, Angela) already exists.
# CONTEXT:  COPY actor, line 1
# ERROR:  duplicate key value violates unique constraint "pelicula_pkey"
# DETAIL:  Key (nombre, anho)=(The Shawshank Redemption, 1994) already exists.
# CONTEXT:  COPY pelicula, line 1
# ERROR:  duplicate key value violates unique constraint "personaje_pkey"
# DETAIL:  Key (a_nombre, p_nombre, p_anho, personaje)=(Aames, Angela, Scarface, 1983, Woman at Babylon Club) already exists.
# CONTEXT:  COPY personaje, line 1
# ERROR:  multiple primary keys for table "actor" are not allowed
# ERROR:  multiple primary keys for table "pelicula" are not allowed
# ERROR:  multiple primary keys for table "personaje" are not allowed
# ERROR:  constraint "personaje_a_nombre_fkey" for relation "personaje" already exists
# ERROR:  constraint "personaje_p_nombre_fkey" for relation "personaje" already exists
# GRANT
# GRANT
# GRANT
# GRANT
# ALTER DEFAULT PRIVILEGES
# ALTER DEFAULT PRIVILEGES
#  * postgresql+psycopg2://@/postgres
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Ejecute la siguiente consulta para probar que todo ande bien:

# %%
# %sql select * from pelicula;
# Out:
#  * postgresql+psycopg2://@/postgres
#                                 nombre  anho  calificacion
# 0             The Shawshank Redemption  1994           9.2
# 1                        The Godfather  1972           9.2
# 2               The Godfather: Part II  1974           9.0
# 3                      The Dark Knight  2008           8.9
# 4                         12 Angry Men  1957           8.9
# ..                                 ...   ...           ...
# 245                  The King's Speech  2010           8.0
# 246                       The Avengers  2012           8.0
# 247  Lagaan: Once Upon a Time in India  2001           8.0
# 248               Beauty and the Beast  1991           8.0
# 249                        Kumonosu-jô  1957           8.0
#
# [250 rows x 3 columns]

# %% [markdown]
# Para ejecutar consultas multi-lineas use el tag %%sql:

# %%
# %%sql
# SELECT * FROM
# pelicula
# where nombre ilike '%terminator%';
# Out:
#  * postgresql+psycopg2://@/postgres
#                        nombre  anho  calificacion
# 0  Terminator 2: Judgment Day  1991           8.5
# 1              The Terminator  1984           8.0

# %% [markdown]
# Ahora, debe diseñar las consultas que resuelvan las siguientes preguntas usando los operadores vistos en clases.
#
# #SQL
# ## Pregunta 1
# Las películas de los 80s, ordenadas por calificación de mayor a menor.

# %%
# %%sql
# SELECT *
# FROM pelicula
# WHERE anho BETWEEN 1980 AND 1989
# ORDER BY  calificacion desc
# Out:
#  * postgresql+psycopg2://@/postgres
#                                             nombre  anho  calificacion
# 0   Star Wars: Episode V - The Empire Strikes Back  1980           8.7
# 1                          Raiders of the Lost Ark  1981           8.5
# 2                               Back to the Future  1985           8.5
# 3                            Nuovo Cinema Paradiso  1988           8.4
# 4                                      The Shining  1980           8.4
# 5                                   Hotaru no haka  1988           8.4
# 6                                           Aliens  1986           8.4
# 7                      Once Upon a Time in America  1984           8.4
# 8                                         Das Boot  1981           8.3
# 9       Star Wars: Episode VI - Return of the Jedi  1983           8.3
# 10                                         Amadeus  1984           8.3
# 11                               Full Metal Jacket  1987           8.3
# 12                                        Scarface  1983           8.3
# 13              Indiana Jones and the Last Crusade  1989           8.3
# 14                                     Raging Bull  1980           8.2
# 15                                        Die Hard  1988           8.2
# 16                                Tonari no Totoro  1988           8.2
# 17                                             Ran  1985           8.2
# 18                                    Blade Runner  1982           8.2
# 19                                The Elephant Man  1980           8.2
# 20                                       The Thing  1982           8.1
# 21                                    Idi i smotri  1985           8.1
# 22                                         Platoon  1986           8.1
# 23                                     Stand by Me  1986           8.1
# 24                              The Princess Bride  1987           8.1
# 25                        Kaze no tani no Naushika  1984           8.1
# 26                                          Gandhi  1982           8.0
# 27                                  The Terminator  1984           8.0
# 28                          Tenkû no shiro Rapyuta  1986           8.0
# 29                             Fanny och Alexander  1982           8.0

# %% [markdown]
# ## Pregunta 2
# Los nombres de los personajes que ha interpretado su actriz/actor favorito en los datos, ordenados por año.

# %%
# %%sql
# SELECT personaje
# from personaje
# where a_nombre = 'Pitt, Brad'
# ORDER BY p_anho
# Out:
#  * postgresql+psycopg2://@/postgres
#         personaje
# 0           Mills
# 1  Jeffrey Goines
# 2    Tyler Durden
# 3   Mickey O'Neil
# 4  Lt. Aldo Raine
# 5            Bass

# %% [markdown]
# # Pregunta 3
# Las películas en las que participó su actriz/actor favorito en los datos, ordenadas por calificación de mayor a menor.

# %% [markdown]
# *texto en cursiva*#Guía: SQL
#
# En esta guía usted deberá realizar consultas SQL en un servidor virtual con PostgreSQL que contiene
# datos de películas extraídos de IMDb. El esquema de los datos es el siguiente:
#
# * $\color{green}{\textbf{pelicula}}(\color{blue}{\underline{\text{nombre}}}, \color{blue}{\underline{\text{anho}}}, \color{blue}{\text{calificacion}})$
# * $\color{green}{\textbf{actor}}(\color{blue}{\underline{\text{nombre}}}, \color{blue}{\text{genero}})$
# * $\color{green}{\textbf{personaje}}(\color{blue}{\underline{\text{p_nombre}}}, \color{blue}{\underline{\text{p_anho}}},  \color{blue}{\underline{\text{a_nombre}}}, \color{blue}{\underline{\text{personaje}}})$
#
# La tabla $\color{green}{\textbf{personaje}}$ usa llaves foráneas que hacen referencia a las tablas de $\color{green}{\textbf{actor}}(\color{blue}{\underline{\text{a_nombre}}})$ y $\color{green}{\textbf{pelicula}}(\color{blue}{\underline{\text{p_nombre}}}, \color{blue}{\underline{\text{p_anho}}})$.

# %%
# %%sql
# select p.nombre from pelicula as p, personaje as a
# where a.a_nombre = 'Pitt, Brad'
# and a.p_nombre = p.nombre
# order by p.calificacion desc
# Out:
#  * postgresql+psycopg2://@/postgres
#                  nombre
# 0            Fight Club
# 1                 Se7en
# 2               Snatch.
# 3  Inglourious Basterds
# 4      12 Years a Slave
# 5        Twelve Monkeys

# %% [markdown]
# ## Pregunta 4
# Los nombres de los personajes interpretados por mujeres, en películas de los 90s, con calificación mayor a 8,7.

# %%
# %%sql
# SELECT *
# FROM pelicula P, actor A, personaje J
# WHERE a_nombre=A.nombre
#   AND P.nombre = p_nombre
#   AND P.anho = p_anho
#   AND p_anho >= 1990 AND p_anho < 2000
#   AND P.calificacion > 8.7
#   AND A.genero = 'F'
# Out:
#  * postgresql+psycopg2://@/postgres
#               nombre  anho  calificacion                nombre genero  \
# 0       Pulp Fiction  1994           8.9           Allman, Cie      F
# 1       Pulp Fiction  1994           8.9      Arquette, Alexis      F
# 2       Pulp Fiction  1994           8.9     Arquette, Rosanna      F
# 3   Schindler's List  1993           8.9           Bau, Rebeka      F
# 4   Schindler's List  1993           8.9  Bednarczyk, Dominika      F
# ..               ...   ...           ...                   ...    ...
# 79      Pulp Fiction  1994           8.9   Valentino, Venessia      F
# 80  Schindler's List  1993           8.9     Wagner, Agnieszka      F
# 81  Schindler's List  1993           8.9  Wyrobiec-Bank, Lidia      F
# 82  Schindler's List  1993           8.9      Yerushalmi, Esti      F
# 83  Schindler's List  1993           8.9        Zabawa, Lucyna      F
#
#                 a_nombre          p_nombre  p_anho  \
# 0            Allman, Cie      Pulp Fiction    1994
# 1       Arquette, Alexis      Pulp Fiction    1994
# 2      Arquette, Rosanna      Pulp Fiction    1994
# 3            Bau, Rebeka  Schindler's List    1993
# 4   Bednarczyk, Dominika  Schindler's List    1993
# ..                   ...               ...     ...
# 79   Valentino, Venessia      Pulp Fiction    1994
# 80     Wagner, Agnieszka  Schindler's List    1993
# 81  Wyrobiec-Bank, Lidia  Schindler's List    1993
# 82      Yerushalmi, Esti  Schindler's List    1993
# 83        Zabawa, Lucyna  Schindler's List    1993
#
#                               personaje
# 0   Winston Wolfe's Girlfriend At Party
# 1                            Fourth Man
# 2                                  Jody
# 3           Herself - Schindler Mourner
# 4                           Ghetto Girl
# ..                                  ...
# 79                       Bonnie Dimmick
# 80                       Brinnlitz Girl
# 81                      Clara Sternberg
# 82                  Plaszow Jewish Girl
# 83                         Ghetto Woman
#
# [84 rows x 9 columns]

# %%
# %%sql
# select * from pelicula as p, actor as a, personaje as per
# where a.genero = 'F' and p.anho between 1989 and 2000 and p.calificacion > 8.7
# and a.nombre=per.a_nombre
# and p.nombre= per.p_nombre
# Out:
#  * postgresql+psycopg2://@/postgres
#               nombre  anho  calificacion                nombre genero  \
# 0       Pulp Fiction  1994           8.9           Allman, Cie      F
# 1       Pulp Fiction  1994           8.9      Arquette, Alexis      F
# 2       Pulp Fiction  1994           8.9     Arquette, Rosanna      F
# 3   Schindler's List  1993           8.9           Bau, Rebeka      F
# 4   Schindler's List  1993           8.9  Bednarczyk, Dominika      F
# ..               ...   ...           ...                   ...    ...
# 79      Pulp Fiction  1994           8.9   Valentino, Venessia      F
# 80  Schindler's List  1993           8.9     Wagner, Agnieszka      F
# 81  Schindler's List  1993           8.9  Wyrobiec-Bank, Lidia      F
# 82  Schindler's List  1993           8.9      Yerushalmi, Esti      F
# 83  Schindler's List  1993           8.9        Zabawa, Lucyna      F
#
#                 a_nombre          p_nombre  p_anho  \
# 0            Allman, Cie      Pulp Fiction    1994
# 1       Arquette, Alexis      Pulp Fiction    1994
# 2      Arquette, Rosanna      Pulp Fiction    1994
# 3            Bau, Rebeka  Schindler's List    1993
# 4   Bednarczyk, Dominika  Schindler's List    1993
# ..                   ...               ...     ...
# 79   Valentino, Venessia      Pulp Fiction    1994
# 80     Wagner, Agnieszka  Schindler's List    1993
# 81  Wyrobiec-Bank, Lidia  Schindler's List    1993
# 82      Yerushalmi, Esti  Schindler's List    1993
# 83        Zabawa, Lucyna  Schindler's List    1993
#
#                               personaje
# 0   Winston Wolfe's Girlfriend At Party
# 1                            Fourth Man
# 2                                  Jody
# 3           Herself - Schindler Mourner
# 4                           Ghetto Girl
# ..                                  ...
# 79                       Bonnie Dimmick
# 80                       Brinnlitz Girl
# 81                      Clara Sternberg
# 82                  Plaszow Jewish Girl
# 83                         Ghetto Woman
#
# [84 rows x 9 columns]

# %% [markdown]
# ## Pregunta 5
# Las películas de la saga "The Lord of the Rings" (usando el prefijo de su nombre) ordenadas por calificación y por año.

# %%
# %%sql
# select * from pelicula
# where nombre ilike '%The Lord of the Rings%'
# order by calificacion, anho
# Out:
#  * postgresql+psycopg2://@/postgres
#                                               nombre  anho  calificacion
# 0              The Lord of the Rings: The Two Towers  2002           8.7
# 1  The Lord of the Rings: The Fellowship of the Ring  2001           8.8
# 2      The Lord of the Rings: The Return of the King  2003           8.9

# %% [markdown]
# ## Pregunta 6
# Los nombres de los actores que interpretan más de un personaje en la misma película.

# %%
# %%sql
# select distinct p1.a_nombre
# from personaje p1, personaje p2
# where p1.a_nombre = p2.a_nombre
# and p1.personaje != p2.personaje
# and p1.p_nombre = p2.p_nombre
# Out:
#  * postgresql+psycopg2://@/postgres
#                 a_nombre
# 0        Abbott, Frankie
# 1         Abbou, Bernard
# 2            Adán, Pablo
# 3      Alazraqui, Carlos
# 4        Albertson, Jeff
# ..                   ...
# 321  Wisher Jr., William
# 322        Worsham, John
# 323    Yee, Mitchell (I)
# 324      Yoshida, Rihoko
# 325      Young, John (I)
#
# [326 rows x 1 columns]

# %% [markdown]
# ## Pregunta 7
# Las películas en que actúan juntos Uma Thurman y Samuel L. Jackson.

# %%
# %%sql
# select *
# from personaje p1, personaje p2
# where p2.a_nombre = 'Jackson, Samuel L.'
# and p1.a_nombre = 'Thurman, Uma'
# and p1.p_nombre = p2.p_nombre
# Out:
#  * postgresql+psycopg2://@/postgres
#        a_nombre      p_nombre  p_anho    personaje            a_nombre  \
# 0  Thurman, Uma  Pulp Fiction    1994  Mia Wallace  Jackson, Samuel L.
#
#        p_nombre  p_anho        personaje
# 0  Pulp Fiction    1994  Jules Winnfield

# %% [markdown]
# ## Pregunta 8
# Las películas en que actúa Uma Thurman y **no** Samuel L. Jackson.

# %%
# %%sql
# select p_nombre
# from personaje
# where a_nombre = 'Thurman, Uma'
# EXCEPT
# select p_nombre
# from personaje
# where a_nombre = 'Jackson, Samuel L.'
# Out:
#  * postgresql+psycopg2://@/postgres
#                    p_nombre
# 0  Kaze no tani no Naushika
# 1         Kill Bill: Vol. 1

# %% [markdown]
# ## Pregunta 9
# Los pares de actores que aparecen juntos en más de una película. Cada par debe aparecer una sola vez, es decir, si $(A,B)$ aparece, no debe aparecer $(B,A)$, pues es el mismo par. Tampoco se deben incluir pares de la forma $(A,A)$.

# %%
# %%sql
# select distinct p1.a_nombre, p2.a_nombre
# from personaje as p1, personaje as p2, personaje as p3, personaje as p4
# where p1.p_nombre = p2.p_nombre
# and p1.a_nombre != p2.a_nombre
# and p1.p_anho = p2.p_anho
#
# and p3.p_nombre = p4.p_nombre
# and p3.a_nombre != p4.a_nombre
# and p3.p_anho = p4.p_anho
#
# and p3.p_nombre <> p1.p_nombre
# and p3.p_anho <> p1.p_anho
#
# and p1.a_nombre = p3.a_nombre
# and p2.a_nombre = p4.a_nombre
# Out:
#  * postgresql+psycopg2://@/postgres
#                 a_nombre          a_nombre
# 0           Abbink, Marc     McCabe, Orion
# 1      Acevedo, Gino (I)     Appleby, Noel
# 2      Acevedo, Gino (I)       Astin, Sean
# 3      Acevedo, Gino (I)       Baker, Sala
# 4      Acevedo, Gino (I)        Bean, Sean
# ...                  ...               ...
# 10747    Young, John (I)        Idle, Eric
# 10748    Young, John (I)   Innes, Neil (I)
# 10749    Young, John (I)  Jones, Terry (I)
# 10750    Young, John (I)    Knode, Charles
# 10751    Young, John (I)    Palin, Michael
#
# [10752 rows x 2 columns]

# %% [markdown]
# ## Pregunta 10
# La película con calificación más alta.

# %%
# %%sql
# select max(calificacion)
# from pelicula
# Out:
#  * postgresql+psycopg2://@/postgres
#    max
# 0  9.2

# %%
# %%sql
# select nombre
# from pelicula
# where calificacion=9.2
# Out:
#  * postgresql+psycopg2://@/postgres
#                      nombre
# 0  The Shawshank Redemption
# 1             The Godfather

# %%
# %%sql
# SELECT nombre
# FROM pelicula
# WHERE calificacion = (SELECT MAX(calificacion) FROM pelicula);
# Out:
#  * postgresql+psycopg2://@/postgres
#                      nombre
# 0  The Shawshank Redemption
# 1             The Godfather
